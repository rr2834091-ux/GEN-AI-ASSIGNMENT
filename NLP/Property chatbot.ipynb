# %%
message = input("Buyer: ")
print("Message Received:", message)
import nltk
from nltk.tokenize import word_tokenize
message = input("Buyer: ")
words = word_tokenize(message.lower())
print(words)
properties = [{"location":"singapore","type":"2 bhk","price":750000},
              {"location":"singapore","type":"3 bhk","price":950000},
            {"location":"india","type":"2 bhk","price":500000}]
budget = 800000
for house in properties:
    if house["location"]=="singapore" and house["price"]<=budget:
        print(house)
print("Matching Property Found")
print("Location:", house["location"])
print("Type:", house["type"])
print("Price:", house["price"])
date = input("Enter visit date: ")
time = input("Enter visit time: ")
print(date)
print(time)
seller_number = "+91 9026738102"
print("Sending WhatsApp message...")
print("Buyer wants to visit on", date, time)
seller_reply = "Confirmed"
if seller_reply == "Confirmed":
    print("Seller accepted the visit.")
print("Visit Date:", date)
print("Visit Time:", time)
import pywhatkit
phone='+91 9025738102'
message="Buyer wants to visit the property on 29-07-2026 at 11:00 AM."
pywhatkit.sendwhatmsg_instantly(
    phone,
    message,
    wait_time=30,
    tab_close=True
)
# Out:
# Buyer:  hi,I need a 2 BHK house in singapore underSGD 800000
# Message Received: hi,I need a 2 BHK house in singapore underSGD 800000
# Buyer:  hi,I need a 2 BHK house in singapore underSGD 800000
# ['hi', ',', 'i', 'need', 'a', '2', 'bhk', 'house', 'in', 'singapore', 'undersgd', '800000']
# {'location': 'singapore', 'type': '2 bhk', 'price': 750000}
# Matching Property Found
# Location: india
# Type: 2 bhk
# Price: 500000
# Enter visit date:  28-07-2026
# Enter visit time:  10:31PM
# 28-07-2026
# 10:31PM
# Sending WhatsApp message...
# Buyer wants to visit on 28-07-2026 10:31PM
# Seller accepted the visit.
# Visit Date: 28-07-2026
# Visit Time: 10:31PM

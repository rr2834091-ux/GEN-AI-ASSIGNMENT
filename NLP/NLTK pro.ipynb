# %%
#Linked in webiste NLTK :
import urllib.request
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
data=urllib.request.urlopen('https://www.linkedin.com/feed')
content=data.read()
soup=BeautifulSoup(content)
content_data = soup.get_text(strip=True)
s_data = [i for i in content_data.split()] # list comprehension
print(s_data)
#len(s_data)
data=urllib.request.urlopen('https://www.linkedin.com/feed')
content=data.read()
soup=BeautifulSoup(content)
content_data=soup.get_text(strip=True)
s_data=[i for i in content_data.split()]
fq=nltk.FreqDist(s_data)
for k,v in fq.items():
    print(str(k),':',str(v))
#Trying to remove stop words
>>> import nltk
>>>nltk.download('punkt_tab')
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('stopwords')
data =urllib.request.urlopen('https://www.linkedin.com/feed')
content=data.read()
soup=BeautifulSoup(content)
text_data=soup.get_text(strip=True)
tkn=[i for i in text_data.split()]
clear_tkn=tkn[:]
word=stopwords.words('english')
for t in tkn:
    if t in stopwords.words('english'):
        clear_tkn.remove(t)
#stop words tamil:
stopwords_list=set(stopwords.words('tamil'))
for i in stopwords_list:
    print(i)
#SYNONYMS:
from nltk.corpus import wordnet
synonym_list=[]
for i in wordnet.synsets('lemma'):
    for j in i.lemmas():
        synonym_list.append(j.name())
print(synonym_list)
#ANTONYMS:
antonym_list=[]
for i in wordnet.synsets('Online'):
    for j in i.lemmas():
        if j.antonyms():
            antonym_list.append(j.antonyms()[0].name())
print(antonym_list)
#PorterStemmer:
print('PorterStemmer')
print('-'*15)
from nltk.stem import PorterStemmer
word=PorterStemmer()
print(word.stem('travelling'))
print(word.stem('snezzing'))
print(word.stem('population'))
print(word.stem('visualizing'))
print(word.stem('economical'))
print(word.stem('Judgement'))
#LancasterStemmer:
print('-'*15)
print('LancasterStemmer')
print('-'*15)
from nltk.stem import LancasterStemmer
word=LancasterStemmer()
print(word.stem('travelling'))
print(word.stem('snezzing'))
print(word.stem('population'))
print(word.stem('visualizing'))
print(word.stem('economical'))
print(word.stem('Judgement'))
#SnowballStemmer:
print('-'*20)
print('SnowballStemmer')
print('-'*20)
from nltk.stem import SnowballStemmer
print(SnowballStemmer.languages)
word=SnowballStemmer('english')
print(word.stem('concentration'))
print(word.stem('liking'))
print(word.stem('thinking'))
print(word.stem('fishing'))
print(word.stem('disgraceful'))
# Out:
# ['LinkedIn', 'Login,', 'Sign', 'in', '|', 'LinkedIn0', 'notificationsSign', 'inNew', 'to', 'LinkedIn?Join', 'nowSign', 'in', 'with', 'AppleBy', 'continuing,', 'you', 'agree', 'to', 'LinkedIn’sUser', 'Agreement,Privacy', 'Policy,', 'andCookie', 'Policy.orEmail', 'or', 'phonePasswordForgot', 'password?Keep', 'me', 'signed', 'inSign', 'inSign', 'inNew', 'to', 'LinkedIn?Join', 'nowSign', 'in', 'with', 'AppleBy', 'continuing,', 'you', 'agree', 'to', 'LinkedIn’sUser', 'Agreement,Privacy', 'Policy,', 'andCookie', 'Policy.orEmail', 'or', 'phonePasswordForgot', 'password?Keep', 'me', 'signed', 'inSign', 'inUser', 'AgreementPrivacy', 'PolicyCommunity', 'GuidelinesCookie', 'PolicyCopyright', 'PolicySend', 'FeedbackLanguageLinkedIn', 'Corporation', '©', '2026LinkedIn', 'Corporation', '©', '2026User', 'AgreementPrivacy', 'PolicyCommunity', 'GuidelinesCookie', 'PolicyCopyright', 'PolicySend', 'FeedbackLanguage']
# LinkedIn : 1
# Login, : 1
# Sign : 1
# in : 3
# | : 1
# LinkedIn0 : 1
# ...
